# %% [markdown]
# # Exercício 10 — SQL: CTEs (Common Table Expressions)
#
# **Tópico:** SQL intermediário — WITH, CTE simples, CTE encadeada
# **Sintaxe:** Use `%sql` no Databricks ou `spark.sql()`
#
# ---
#
# ## Setup
# Carregue `pedidos.csv`, `clientes.csv` e `funcionarios.csv` e crie temp views.
#
# ---
#
# ## Exercício 1 — CTE simples
# Usando CTE, calcule o **total gasto por cliente** (soma de `valor_total` em pedidos).
# Na query principal, filtre apenas clientes que gastaram mais de R$ 5.000.
#
# ```sql
# WITH gasto_por_cliente AS (
#     ...
# )
# SELECT ...
# FROM gasto_por_cliente
# WHERE ...
# ```
#
# ---
#
# ## Exercício 2 — CTE com JOIN
# Crie uma CTE que calcula o total de pedidos por `cliente_id`.
# Depois faça um JOIN dessa CTE com a tabela `clientes` para trazer o nome do cliente junto.
# Ordene pelo total decrescente.
#
# ---
#
# ## Exercício 3 — Múltiplas CTEs encadeadas
# Crie duas CTEs:
# - `media_salario`: calcula o salário médio por departamento (de `funcionarios`)
# - `acima_da_media`: lista funcionários que ganham acima da média do seu departamento
#
# Na query final, exiba nome, departamento, salário e a média do departamento.
#
# ---
#
# ## Exercício 4 — CTE para ranking
# Usando CTE, crie uma query que:
# 1. Calcula o valor total de cada pedido por categoria
# 2. Rankeia as categorias por total (maior para menor)
# 3. Exibe apenas o top 3
#
# ---
#
# ## Exercício 5 — CTE vs Subquery
# Reescreva a query do exercício 1 usando uma **subquery** em vez de CTE.
# Compare as duas abordagens e comente qual é mais legível e por quê.

# %%
PEDIDOS_PATH      = "/FileStore/tables/pedidos.csv"
CLIENTES_PATH     = "/FileStore/tables/clientes.csv"
FUNCIONARIOS_PATH = "/FileStore/tables/funcionarios.csv"

# carregue os DataFrames e crie as temp views aqui

# %%
# Exercício 1

# %%
# Exercício 2

# %%
# Exercício 3

# %%
# Exercício 4

# %%
# Exercício 5

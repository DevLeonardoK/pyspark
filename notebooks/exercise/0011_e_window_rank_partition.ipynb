# %% [markdown]
# # Exercício 11 — Window Functions: RANK e PARTITION BY
#
# **Tópico:** SQL — Window Functions, RANK, DENSE_RANK, ROW_NUMBER, PARTITION BY
# **Sintaxe:** Use `%sql` no Databricks ou `spark.sql()`
#
# ---
#
# ## Setup
# Carregue `vendas.csv`, `funcionarios.csv` e `pedidos.csv` e crie temp views.
#
# ---
#
# ## Exercício 1 — RANK geral
# Usando `vendas`, ranqueie todos os registros pelo `valor` de forma decrescente usando `RANK()`.
# Exiba `produto`, `valor`, `vendedor` e o ranking.
# O que acontece quando dois registros têm o mesmo valor?
#
# ---
#
# ## Exercício 2 — RANK por categoria (PARTITION BY)
# Ranqueie os produtos **dentro de cada categoria** pelo `valor` decrescente.
# Exiba `categoria`, `produto`, `valor` e `rank_na_categoria`.
#
# ---
#
# ## Exercício 3 — DENSE_RANK vs RANK vs ROW_NUMBER
# Usando `funcionarios`, ranqueie os funcionários por `salario` decrescente usando os três métodos:
# - `RANK()`
# - `DENSE_RANK()`
# - `ROW_NUMBER()`
#
# Exiba as três colunas juntas e observe as diferenças quando salários são iguais.
#
# ---
#
# ## Exercício 4 — Top 1 por grupo
# Usando `RANK()` com `PARTITION BY`, encontre o **produto mais vendido** (por `quantidade`) de cada `categoria` em `vendas`.
# Dica: faça um CTE com o rank e depois filtre `rank = 1`.
#
# ---
#
# ## Exercício 5 — Média por partição vs total
# Usando `vendas`, calcule para cada linha:
# - A média de `valor` **geral** (sem partition)
# - A média de `valor` **por região** (com partition by regiao)
# - A diferença entre o `valor` da venda e a média da sua região
#
# Isso mostra se cada venda ficou acima ou abaixo da média da sua região.

# %%
VENDAS_PATH       = "/FileStore/tables/vendas.csv"
FUNCIONARIOS_PATH = "/FileStore/tables/funcionarios.csv"
PEDIDOS_PATH      = "/FileStore/tables/pedidos.csv"

# carregue os DataFrames e crie as temp views aqui

# %%
# Exercício 1

# %%
# Exercício 2

# %%
# Exercício 3

# %%
# Exercício 4

# %%
# Exercício 5

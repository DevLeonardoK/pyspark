# %% [markdown]
# # Exercício 12 — Window Functions: Sliding Windows (Janelas Deslizantes)
#
# **Tópico:** SQL — ROWS BETWEEN, running total, média móvel
# **Sintaxe:** Use `%sql` no Databricks ou `spark.sql()`
#
# ---
#
# ## Setup
# Carregue `vendas.csv` e crie uma temp view `vendas`.
#
# ---
#
# ## Exercício 1 — Running Total (acumulado)
# Calcule o **total acumulado de valor** ao longo do tempo (ordene por `data`).
# Use `SUM() OVER (ORDER BY data ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW)`.
# Exiba `data`, `produto`, `valor` e `total_acumulado`.
#
# ---
#
# ## Exercício 2 — Média móvel de 3 registros
# Calcule a **média móvel de 3 registros** do `valor` (o atual + 2 anteriores), ordenando por `data`.
# Use `AVG() OVER (ORDER BY data ROWS BETWEEN 2 PRECEDING AND CURRENT ROW)`.
# Exiba `data`, `valor` e `media_movel_3`.
#
# ---
#
# ## Exercício 3 — Running Total por região
# Calcule o acumulado de `valor * quantidade` **separado por região** (usando PARTITION BY).
# Ordene por `regiao` e `data`.
# Exiba `regiao`, `data`, `produto`, `valor`, `quantidade` e `acumulado_regiao`.
#
# ---
#
# ## Exercício 4 — Running Average com UNBOUNDED FOLLOWING
# Calcule uma média "do futuro" — do registro atual até o final da série — usando:
# `AVG(valor) OVER (ORDER BY data ROWS BETWEEN CURRENT ROW AND UNBOUNDED FOLLOWING)`
# Exiba `data`, `valor` e `media_ate_fim`.
# O que esse valor representa na prática?
#
# ---
#
# ## Exercício 5 — Comparação entre janelas
# Na mesma query, calcule as três janelas abaixo para cada registro de `vendas`:
# - `soma_3_anteriores`: soma dos 3 registros anteriores + atual
# - `soma_acumulada`: soma de tudo desde o início
# - `soma_total`: soma de todos os registros (sem partition, sem order — janela inteira)
#
# Adicione uma coluna `pct_do_total` = `valor / soma_total * 100`.

# %%
VENDAS_PATH = "/FileStore/tables/vendas.csv"

# carregue o DataFrame e crie a temp view aqui

# %%
# Exercício 1

# %%
# Exercício 2

# %%
# Exercício 3

# %%
# Exercício 4

# %%
# Exercício 5

# %% [markdown]
# # Exercício 09 — SQL: UNION, INTERSECT e todos os JOINs
#
# **Tópico:** SQL intermediário — UNION, INTERSECT, INNER/LEFT/RIGHT/FULL JOIN
# **Sintaxe:** Use `%sql` no Databricks ou `spark.sql()`
#
# ---
#
# ## Setup
# Faça o upload de `clientes.csv`, `pedidos.csv` e `funcionarios.csv` para o DBFS
# e crie temp views para cada um:
# ```python
# df_clientes.createOrReplaceTempView("clientes")
# df_pedidos.createOrReplaceTempView("pedidos")
# df_funcionarios.createOrReplaceTempView("funcionarios")
# ```
#
# ---
#
# ## Exercício 1 — UNION
# Crie duas queries:
# - Query A: selecione `nome` e `cidade` de `clientes` onde `segmento = 'Empresa'`
# - Query B: selecione `nome` e `cidade` de `funcionarios`
#
# Use `UNION` para combinar os resultados (removendo duplicatas).
# Depois use `UNION ALL` e compare a diferença no número de linhas.
#
# ---
#
# ## Exercício 2 — INTERSECT
# Encontre cidades que aparecem **tanto** em `clientes` **quanto** em `funcionarios`
# usando `INTERSECT`.
#
# ---
#
# ## Exercício 3 — INNER JOIN
# Faça um `INNER JOIN` entre `clientes` e `pedidos` em `clientes.id = pedidos.cliente_id`.
# Exiba `nome` do cliente, `produto`, `quantidade`, `valor_total` e `status`.
#
# ---
#
# ## Exercício 4 — LEFT JOIN e clientes sem pedidos
# Faça um `LEFT JOIN` de `clientes` com `pedidos`.
# Filtre apenas os clientes que **não têm nenhum pedido** (`pedidos.id IS NULL`).
#
# ---
#
# ## Exercício 5 — FULL JOIN e análise completa
# Faça um `FULL JOIN` entre `clientes` e `pedidos`.
# Mostre:
# - Clientes com pedidos
# - Clientes sem pedidos
# - (se houver) Pedidos sem cliente associado
#
# Adicione uma coluna `tipo` com o valor `'com pedido'` ou `'sem pedido'` usando `CASE WHEN`.

# %%
CLIENTES_PATH     = "/FileStore/tables/clientes.csv"
PEDIDOS_PATH      = "/FileStore/tables/pedidos.csv"
FUNCIONARIOS_PATH = "/FileStore/tables/funcionarios.csv"

# carregue os DataFrames e crie as temp views aqui

# %%
# Exercício 1

# %%
# Exercício 2

# %%
# Exercício 3

# %%
# Exercício 4

# %%
# Exercício 5

# %% [markdown]
# # Exercício 13 — Window Functions: LAG e LEAD
#
# **Tópico:** SQL — LAG(), LEAD(), comparação entre períodos
# **Sintaxe:** Use `%sql` no Databricks ou `spark.sql()`
#
# ---
#
# ## Setup
# Carregue `vendas.csv` e `funcionarios.csv` e crie temp views.
#
# ---
#
# ## Exercício 1 — LAG: valor anterior
# Para cada registro de `vendas` (ordenado por `data`), traga o `valor` da venda **anterior** usando `LAG`.
# Exiba `data`, `produto`, `valor` e `valor_anterior`.
# O primeiro registro terá `NULL` em `valor_anterior` — isso é esperado.
#
# ---
#
# ## Exercício 2 — LEAD: próximo valor
# Para cada registro de `vendas`, traga o `valor` da **próxima** venda usando `LEAD`.
# Exiba `data`, `produto`, `valor` e `proxima_venda`.
#
# ---
#
# ## Exercício 3 — Variação entre vendas
# Calcule a **variação** entre o valor atual e o valor anterior:
# `variacao = valor - LAG(valor)`
# Adicione também uma coluna `tendencia` com `'subiu'`, `'caiu'` ou `'igual'` usando `CASE WHEN`.
# Ordene por `data`.
#
# ---
#
# ## Exercício 4 — LAG com PARTITION BY (por vendedor)
# Calcule a variação de valor **separada por vendedor** — cada vendedor tem sua própria sequência.
# Use `LAG(valor) OVER (PARTITION BY vendedor ORDER BY data)`.
# Exiba `vendedor`, `data`, `valor` e `valor_anterior_mesmo_vendedor`.
#
# ---
#
# ## Exercício 5 — Comparação mês a mês
# Agrupe as vendas por mês (`DATE_TRUNC` ou `MONTH()`) e calcule o total mensal.
# Depois use `LAG` para trazer o total do mês anterior e calcule o crescimento percentual:
# `crescimento_pct = (total_mes - total_mes_anterior) / total_mes_anterior * 100`

# %%
VENDAS_PATH       = "/FileStore/tables/vendas.csv"
FUNCIONARIOS_PATH = "/FileStore/tables/funcionarios.csv"

# carregue os DataFrames e crie as temp views aqui

# %%
# Exercício 1

# %%
# Exercício 2

# %%
# Exercício 3

# %%
# Exercício 4

# %%
# Exercício 5
